# %%
import numpy as np
import matplotlib.pyplot as plt

from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.models import Model
from keras.layers import Flatten, Dense

from keras.preprocessing.image import ImageDataGenerator#, img_to_array, load_img

# %%
base_model = MobileNet

# %%
import os
import shutil

# %%
sad = 'images/train/sad'
os.path.exists(sad)
# Out:
# True

# %%
emotions= ['angry', 'sad', 'happy', 'disgust', 'surprise', 'fear', 'neutral']
path = os.listdir('images/train')
for j in emotions:
    path1= "images/train/" + str(j)
    for i in os.listdir(path1)[:1000]:
        source= os.path.join(path1, i)
        destination = 'emotions/train/' + str(j)
        #os.mkdir("C:/Users/HR/Documents/Jupyter Notebooks/Real Time Object Detection/Facial Emotions/emotions/train/" + str(j) +"/" + str(i))
        shutil.copy(source, destination)

# %%
emotions= ['angry', 'sad', 'happy', 'disgust', 'surprise', 'fear', 'neutral']
path = os.listdir('images/validation')
for j in emotions:
    path1= "images/validation/" + str(j)
    for i in os.listdir(path1)[:50]:
        source= os.path.join(path1, i)
        destination = 'emotions/validation/' + str(j)
        #os.mkdir("C:/Users/HR/Documents/Jupyter Notebooks/Real Time Object Detection/Facial Emotions/emotions/train/" + str(j) +"/" + str(i))
        shutil.copy(source, destination)

# %%
emotions= ['angry', 'sad', 'happy', 'disgust', 'surprise', 'fear', 'neutral']
path = os.listdir('images/train')
for j in emotions:
    path1= "images/validation/" + str(j)
    for i in os.listdir(path1)[:250]:
        source= os.path.join(path1, i)
        destination = 'emotions/test/' + str(j)
        #os.mkdir("C:/Users/HR/Documents/Jupyter Notebooks/Real Time Object Detection/Facial Emotions/emotions/train/" + str(j) +"/" + str(i))
        shutil.copy(source, destination)

# %%
os.listdir("images/train/angry")
# Out:
# ['0.jpg',
#  '1.jpg',
#  '10.jpg',
#  '10002.jpg',
#  '10016.jpg',
#  '10037.jpg',
#  '10038.jpg',
#  '10057.jpg',
#  '10063.jpg',
#  '10069.jpg',
#  '10100.jpg',
#  '10105.jpg',
#  '10115.jpg',
#  '10122.jpg',
#  '10142.jpg',
#  '1015.jpg',
#  '10154.jpg',
#  '10155.jpg',
#  '10158.jpg',
#  '1016.jpg',
#  '10167.jpg',
#  '10178.jpg',
#  '1018.jpg',
#  '10181.jpg',
#  '10192.jpg',
#  '10196.jpg',
#  '10202.jpg',
#  '10207.jpg',
#  '10214.jpg',
#  '10223.jpg',
#  '10226.jpg',
#  '10240.jpg',
#  '10242.jpg',
#  '10250.jpg',
#  '10251.jpg',
#  '10253.jpg',
#  '10265.jpg',
#  '10287.jpg',
#  '10302.jpg',
#  '10310.jpg',
#  '10325.jpg',
#  '10348.jpg',
#  '10359.jpg',
#  '10363.jpg',
#  '10364.jpg',
#  '10373.jpg',
#  '10377.jpg',
#  '10378.jpg',
#  '10385.jpg',
#  '10388.jpg',
#  '1039.jpg',
#  '10394.jpg',
#  '10397.jpg',
#  '10401.jpg',
#  '10420.jpg',
#  '10429.jpg',
#  '10430.jpg',
#  '10431.jpg',
#  '10439.jpg',
#  '10440.jpg',
#  '10441.jpg',
#  '10462.jpg',
#  '10472.jpg',
# ...

# %%
parent_path = C:/Users/HR/Documents/Jupyter Notebooks/Real Time Object Detection/Facial Emotions
